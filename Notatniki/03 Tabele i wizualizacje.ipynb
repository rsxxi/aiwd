# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#rozpakowywanie danych
data = pd.read_pickle("Data.pickle")

# %%
data
# Out:
#                                          School Name        Region  \
# 0           California Institute of Technology (CIT)    California
# 1                                Harvey Mudd College    California
# 2                 University of California, Berkeley    California
# 3                                 Occidental College    California
# 4                           Cal Poly San Luis Obispo    California
# ..                                               ...           ...
# 255                          Fitchburg State College  Northeastern
# 256                              University Of Maine  Northeastern
# 257   State University of New York (SUNY) at Potsdam  Northeastern
# 258  State University of New York (SUNY) at Fredonia  Northeastern
# 259                     University of Southern Maine  Northeastern
#
#       School Type  Starting Median Salary  Mid-Career Median Salary  \
# 0     Engineering                 75500.0                  123000.0
# 1     Engineering                 71800.0                  122000.0
# 2           State                 59900.0                  112000.0
# 3    Liberal Arts                 51900.0                  105000.0
# 4           State                 57200.0                  101000.0
# ..            ...                     ...                       ...
# 255         State                 42400.0                   72600.0
# 256         State                 41200.0                   72100.0
# 257         State                 38000.0                   70300.0
# 258         State                 37800.0                   66200.0
# 259         State                 39400.0                   63600.0
#
#      Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                              62650.0                           104000.0
# 1                              62650.0                            96000.0
# 2                              59500.0                            81000.0
# 3                                  NaN                            54800.0
# 4                              55000.0                            74700.0
# ..                                 ...                                ...
# 255                            43300.0                            56100.0
# 256                            41700.0                            55600.0
# 257                            35100.0                            51200.0
# 258                            32800.0                            44200.0
# 259                            40400.0                            47900.0
#
#      Mid-Career 75th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                             161000.0                      175571.428571
# 1                             180000.0                      175571.428571
# 2                             149000.0                      201000.000000
# 3                             157000.0                                NaN
# 4                             133000.0                      178000.000000
# ..                                 ...                                ...
# 255                            99600.0                      151000.000000
# 256                            99300.0                      141000.000000
# 257                           100000.0                      179000.000000
# 258                            93300.0                      181000.000000
# 259                            85700.0                      117000.000000
#
# [260 rows x 9 columns]

# %%
#Dodanie kolumny z różnicą zarobków z początku i środka kariery
data["Difference Between Mid-Career and Starting Salary"] = data["Mid-Career Median Salary"] - data["Starting Median Salary"]

# %%
data
# Out:
#                                          School Name        Region  \
# 0           California Institute of Technology (CIT)    California
# 1                                Harvey Mudd College    California
# 2                 University of California, Berkeley    California
# 3                                 Occidental College    California
# 4                           Cal Poly San Luis Obispo    California
# ..                                               ...           ...
# 255                          Fitchburg State College  Northeastern
# 256                              University Of Maine  Northeastern
# 257   State University of New York (SUNY) at Potsdam  Northeastern
# 258  State University of New York (SUNY) at Fredonia  Northeastern
# 259                     University of Southern Maine  Northeastern
#
#       School Type  Starting Median Salary  Mid-Career Median Salary  \
# 0     Engineering                 75500.0                  123000.0
# 1     Engineering                 71800.0                  122000.0
# 2           State                 59900.0                  112000.0
# 3    Liberal Arts                 51900.0                  105000.0
# 4           State                 57200.0                  101000.0
# ..            ...                     ...                       ...
# 255         State                 42400.0                   72600.0
# 256         State                 41200.0                   72100.0
# 257         State                 38000.0                   70300.0
# 258         State                 37800.0                   66200.0
# 259         State                 39400.0                   63600.0
#
#      Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                              62650.0                           104000.0
# 1                              62650.0                            96000.0
# 2                              59500.0                            81000.0
# 3                                  NaN                            54800.0
# 4                              55000.0                            74700.0
# ..                                 ...                                ...
# 255                            43300.0                            56100.0
# 256                            41700.0                            55600.0
# 257                            35100.0                            51200.0
# 258                            32800.0                            44200.0
# 259                            40400.0                            47900.0
#
#      Mid-Career 75th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                             161000.0                      175571.428571
# 1                             180000.0                      175571.428571
# 2                             149000.0                      201000.000000
# 3                             157000.0                                NaN
# 4                             133000.0                      178000.000000
# ..                                 ...                                ...
# 255                            99600.0                      151000.000000
# 256                            99300.0                      141000.000000
# 257                           100000.0                      179000.000000
# 258                            93300.0                      181000.000000
# 259                            85700.0                      117000.000000
#
#      Difference Between Mid-Career and Starting Salary
# 0                                              47500.0
# 1                                              50200.0
# 2                                              52100.0
# 3                                              53100.0
# 4                                              43800.0
# ..                                                 ...
# 255                                            30200.0
# 256                                            30900.0
# 257                                            32300.0
# 258                                            28400.0
# 259                                            24200.0
#
# [260 rows x 10 columns]

# %% [markdown]
# # Tabele

# %% [markdown]
# ## Czy początkowe średnie zarobki absolwentów uczelni poszczególnych rodzajów różnią się w zależności od regionu?

# %%
region_start = data.filter(["Region", "School Type", "Starting Median Salary"], axis=1)

# %%
region_start_sort = region_start.groupby(["School Type", "Region"]).median()

# %%
region_start_sort
# Out:
#                            Starting Median Salary
# School Type  Region
# Engineering  California                   73650.0
#              Midwestern                   55900.0
#              Northeastern                 61100.0
#              Southern                     53500.0
#              Western                      54550.0
# Ivy League   California                       NaN
#              Midwestern                       NaN
#              Northeastern                 59850.0
#              Southern                         NaN
#              Western                          NaN
# Liberal Arts California                   48600.0
#              Midwestern                   43400.0
#              Northeastern                 47250.0
#              Southern                     47350.0
#              Western                      40500.0
# Party        California                   50500.0
#              Midwestern                   45500.0
#              Northeastern                 44500.0
#              Southern                     43800.0
#              Western                      47400.0
# State        California                   47600.0
#              Midwestern                   42400.0
#              Northeastern                 44500.0
#              Southern                     43100.0
#              Western                      44900.0

# %% [markdown]
# ## Który region ma najwyższą średnią różnicę między początkowymi a późniejszymi zaróbkami?

# %%
zarobki = data.filter(["Region", "Difference Between Mid-Career and Starting Salary"], axis = 1)

# %%
zarobki_sort = zarobki.groupby(["Region"]).median()

# %%
zarobki_sort
# Out:
#               Difference Between Mid-Career and Starting Salary
# Region
# California                                              41700.0
# Midwestern                                              33700.0
# Northeastern                                            41600.0
# Southern                                                35500.0
# Western                                                 35700.0

# %% [markdown]
# ## Jakie są najwyższe i najniższe mediany zarobków na uczelniach poszczególnych typów?

# %%
imtired = data.groupby("School Type")["Mid-Career Median Salary"].agg(["max", "min"])

# %%
imtired["Difference"] = imtired["max"] - imtired["min"]

# %%
imtired_s = imtired.sort_values(by = "Difference", axis = 0, ascending = True)

# %%
imtired_s
# Out:
#                    max       min  Difference
# School Type
# Party          96100.0   73000.0     23100.0
# Ivy League    134000.0  107000.0     27000.0
# Engineering   126000.0   80000.0     46000.0
# Liberal Arts  110000.0   63900.0     46100.0
# State         112000.0   58200.0     53800.0

# %% [markdown]
# ## Jak duża jest różnica między najwięcej i najmniej zarabiającymi absolwentami szkół z poszczególnych regionów?

# %%
perce = data.groupby("Region")["Mid-Career 10th Percentile Salary", "Mid-Career 90th Percentile Salary"].median()
# Out:
# <ipython-input-16-177f8dfeddc6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   perce = data.groupby("Region")["Mid-Career 10th Percentile Salary", "Mid-Career 90th Percentile Salary"].median()

# %%
perce["Difference"] = perce["Mid-Career 90th Percentile Salary"] - perce["Mid-Career 10th Percentile Salary"]

# %%
perce_s = perce.sort_values(by = "Difference", axis = 0, ascending = True)

# %%
perce_s
# Out:
#               Mid-Career 10th Percentile Salary  \
# Region
# Western                                 41700.0
# Midwestern                              40350.0
# Southern                                42000.0
# California                              47400.0
# Northeastern                            47000.0
#
#               Mid-Career 90th Percentile Salary  Difference
# Region
# Western                                143000.0    101300.0
# Midwestern                             143000.0    102650.0
# Southern                               151000.0    109000.0
# California                             158000.0    110600.0
# Northeastern                           180000.0    133000.0

# %% [markdown]
# ## Jak duża jest różnica między najwięcej i najmniej zarabiającymi absolwentami szkół poszczególnych typów?

# %%
perce2 = data.groupby("School Type")["Mid-Career 10th Percentile Salary", "Mid-Career 90th Percentile Salary"].median()
# Out:
# <ipython-input-20-000c0369fb3d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   perce2 = data.groupby("School Type")["Mid-Career 10th Percentile Salary", "Mid-Career 90th Percentile Salary"].median()

# %%
perce2["Difference"] = perce2["Mid-Career 90th Percentile Salary"] - perce2["Mid-Career 10th Percentile Salary"]

# %%
perce2_s = perce2.sort_values(by = "Difference", axis = 0, ascending = True)

# %%
perce2_s
# Out:
#               Mid-Career 10th Percentile Salary  \
# School Type
# State                                   41900.0
# Engineering                             62650.0
# Party                                   43650.0
# Liberal Arts                            44500.0
# Ivy League                              56350.0
#
#               Mid-Career 90th Percentile Salary     Difference
# School Type
# State                             148000.000000  106100.000000
# Engineering                       175571.428571  112921.428571
# Party                             164500.000000  120850.000000
# Liberal Arts                      189000.000000  144500.000000
# Ivy League                        271500.000000  215150.000000

# %% [markdown]
# # Wizualizacje

# %% [markdown]
# ### 01 Różnice między roczną płacą z początku a z połowy kariery pomiędzy regionami USA

# %%
zarobki_sort = zarobki_sort.sort_values(by = "Difference Between Mid-Career and Starting Salary")

# %%
x = zarobki_sort.index
y = zarobki_sort["Difference Between Mid-Career and Starting Salary"]

fig = plt.figure(figsize=(8,10))

plt.bar(x, y, color=['lightsteelblue', 'lightskyblue', 'skyblue', 'deepskyblue', 'dodgerblue'])

plt.xlabel('Region USA')
plt.ylabel('Różnice między medianą rocznej płacy z początku a ze środka kariery [USD]')
plt.title('Średnie różnice między medianą rocznej płacy z początku \n a ze środka kariery pomiędzy regionami USA')
plt.show()

fig.savefig('wykres_1.png', dpi=500)

# %% [markdown]
# ### 02 Płaca w połowie kariery według uczelni wyższej

# %%
def generuj_wykres(dataset, filename, opis):
    y = dataset["School Name"]
    labels = dataset["School Name"]

    fig = plt.figure(figsize=(15,6))

    x3 = dataset['Mid-Career 10th Percentile Salary']
    plt.scatter(x3, y, color='#bff0f8', label = '10 percentyl zarobków ze środka kariery')
    plt.yticks(y, labels)

    x4 = dataset['Mid-Career 25th Percentile Salary']
    plt.scatter(x4, y, color='#6cb2ef', label = '25 percentyl (Q1) zarobków ze środka kariery')

    x1 = dataset["Mid-Career Median Salary"]
    plt.scatter(x1, y, color='#1986e6', label='Mediana zarobków ze środka kariery')

    x5 = dataset['Mid-Career 75th Percentile Salary']
    plt.scatter(x5, y, color='#8d6cef', label = '75 percentyl (Q3) zarobków ze środka kariery')

    x6 = dataset['Mid-Career 90th Percentile Salary']
    plt.scatter(x6, y, color='#cdbff8', label = '90 percentyl zarobków ze środka kariery')

    #x2 = dataset['Starting Median Salary']
    #plt.scatter(x2, y, color='#ef6c6c', marker="*", label='Mediana zarobków z początku kariery')

    plt.xlabel('Roczne zarobki abolwentów [USD]')
    plt.title(opis)
    plt.legend(loc='lower right')
    plt.show()

    fig.savefig(filename, dpi=300)

# %%
def generuj_wszystko(data, nazwa_wykresu, typ = None):
    mydata = data.sort_values(by = 'Mid-Career Median Salary', ascending=False)
    if typ != None: mydata = mydata[mydata['School Type'] == typ]
    mydata = mydata.head(20)
    mydata = mydata.sort_values(by = 'Mid-Career Median Salary', ascending=True)
    if typ != None: opis_wyk = 'Roczne zarobki absolwentów ' + str(len(mydata.index)) + ' uczelni typu '+ typ +'\n z najwyższą medianą zarobków z kariery'
    else: opis_wyk = 'Roczne zarobki absolwentów ' + str(len(mydata.index)) + ' uczelni \n z najwyższą medianą zarobków ze środka kariery'
    generuj_wykres(mydata, nazwa_wykresu, opis_wyk)

# %%
generuj_wszystko(data,'wykres_2.png')

# %% [markdown]
# ### I dla każdego typu:

# %% [markdown]
# ### Liberal arts

# %%
generuj_wszystko(data, 'wykres_2.1.png', 'Liberal Arts')

# %% [markdown]
# ### State

# %%
generuj_wszystko(data, 'wykres_2.2.png', 'State')

# %% [markdown]
# ### Engineering

# %%
generuj_wszystko(data, 'wykres_2.3.png', 'Engineering')

# %% [markdown]
# ### Party

# %%
generuj_wszystko(data, 'wykres_2.4.png', 'Party')

# %% [markdown]
# ### Ivy League

# %%
generuj_wszystko(data, 'wykres_2.5.png', 'Ivy League')

# %% [markdown]
# ### 03 Korelacja zarobków z początku kariery z zarobkami z połowy kariery

# %%
x = data["Starting Median Salary"]
y = data["Difference Between Mid-Career and Starting Salary"]

fig = plt.figure(figsize=(10,10))

plt.scatter(x, y)

plt.xlabel('Mediana zarobków z początku kariery [USD]')
plt.ylabel('Mediana zarobków ze środka kariery [USD]')
plt.title('Wykres rozrzutu obrazujący korelację mediany zarobków z początku kariery \n z medianą zarobków ze środka kariery wśród absolwentów uczelni amerykańskich')
plt.show()

fig.savefig('wykres_3.png', dpi=500)

# %% [markdown]
# ### 04 Wykres kołowy

# %%
regions = [len(data.loc[data['Region']=='California'].index), len(data.loc[data['Region']=='Midwestern'].index), len(data.loc[data['Region']=='Northeastern'].index), len(data.loc[data['Region']=='Southern'].index), len(data.loc[data['Region']=='Western'].index)]
labels = ['California', 'Midwestern', 'Northeastern', 'Southern', 'Western']

# %%
fig1, ax1 = plt.subplots(figsize=(6,6))
ax1.pie(regions, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')
plt.title("Wykres kołowy przedstawiający udział uczelni \n z różnych regionów w zbiorze danych \n")
plt.show()

fig1.savefig('wykres_6.png', dpi=300)

# %% [markdown]
# ### 05 Wykres pudełkowy

# %%
data
# Out:
#                                          School Name        Region  \
# 0           California Institute of Technology (CIT)    California
# 1                                Harvey Mudd College    California
# 2                 University of California, Berkeley    California
# 3                                 Occidental College    California
# 4                           Cal Poly San Luis Obispo    California
# ..                                               ...           ...
# 255                          Fitchburg State College  Northeastern
# 256                              University Of Maine  Northeastern
# 257   State University of New York (SUNY) at Potsdam  Northeastern
# 258  State University of New York (SUNY) at Fredonia  Northeastern
# 259                     University of Southern Maine  Northeastern
#
#       School Type  Starting Median Salary  Mid-Career Median Salary  \
# 0     Engineering                 75500.0                  123000.0
# 1     Engineering                 71800.0                  122000.0
# 2           State                 59900.0                  112000.0
# 3    Liberal Arts                 51900.0                  105000.0
# 4           State                 57200.0                  101000.0
# ..            ...                     ...                       ...
# 255         State                 42400.0                   72600.0
# 256         State                 41200.0                   72100.0
# 257         State                 38000.0                   70300.0
# 258         State                 37800.0                   66200.0
# 259         State                 39400.0                   63600.0
#
#      Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                              62650.0                           104000.0
# 1                              62650.0                            96000.0
# 2                              59500.0                            81000.0
# 3                                  NaN                            54800.0
# 4                              55000.0                            74700.0
# ..                                 ...                                ...
# 255                            43300.0                            56100.0
# 256                            41700.0                            55600.0
# 257                            35100.0                            51200.0
# 258                            32800.0                            44200.0
# 259                            40400.0                            47900.0
#
#      Mid-Career 75th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                             161000.0                      175571.428571
# 1                             180000.0                      175571.428571
# 2                             149000.0                      201000.000000
# 3                             157000.0                                NaN
# 4                             133000.0                      178000.000000
# ..                                 ...                                ...
# 255                            99600.0                      151000.000000
# 256                            99300.0                      141000.000000
# 257                           100000.0                      179000.000000
# 258                            93300.0                      181000.000000
# 259                            85700.0                      117000.000000
#
#      Difference Between Mid-Career and Starting Salary
# 0                                              47500.0
# 1                                              50200.0
# 2                                              52100.0
# 3                                              53100.0
# 4                                              43800.0
# ..                                                 ...
# 255                                            30200.0
# 256                                            30900.0
# 257                                            32300.0
# 258                                            28400.0
# 259                                            24200.0
#
# [260 rows x 10 columns]

# %%
fig, axs = plt.subplots(2, 3)

x1 = data["Starting Median Salary"]
x2 = data["Mid-Career Median Salary"]
x3 = data["Mid-Career 10th Percentile Salary"]
x4 = data["Mid-Career 25th Percentile Salary"]
x5 = data["Mid-Career 75th Percentile Salary"]
x6 = data["Mid-Career 90th Percentile Salary"]

fig = plt.figure(figsize = (20, 20)) 

axs[0, 0].boxplot(x1)
axs[0, 0].set_title('Starting Median Salary')
axs[0, 1].boxplot(x2)
axs[0, 1].set_title('Mid-Career Median Salary')
axs[0, 2].boxplot(x3)
axs[0, 2].set_title('Mid-Career 10th Percentile Salary')
axs[1, 0].boxplot(x4)
axs[1, 0].set_title('Mid-Career 25th Percentile Salary')
axs[1, 1].boxplot(x5)
axs[1, 1].set_title('Mid-Career 75th Percentile Salary')
axs[1, 2].boxplot(x6)
axs[1, 2].set_title('Mid-Career 90th Percentile Salary')

plt.show()
