# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#rozpakowywanie danych
data = pd.read_pickle("Data.pickle")

# %%
data
# Out:
#                                          School Name        Region  \
# 0           California Institute of Technology (CIT)    California
# 1                                Harvey Mudd College    California
# 2                 University of California, Berkeley    California
# 3                                 Occidental College    California
# 4                           Cal Poly San Luis Obispo    California
# ..                                               ...           ...
# 255                          Fitchburg State College  Northeastern
# 256                              University Of Maine  Northeastern
# 257   State University of New York (SUNY) at Potsdam  Northeastern
# 258  State University of New York (SUNY) at Fredonia  Northeastern
# 259                     University of Southern Maine  Northeastern
#
#       School Type  Starting Median Salary  Mid-Career Median Salary  \
# 0     Engineering                 75500.0                  123000.0
# 1     Engineering                 71800.0                  122000.0
# 2           State                 59900.0                  112000.0
# 3    Liberal Arts                 51900.0                  105000.0
# 4           State                 57200.0                  101000.0
# ..            ...                     ...                       ...
# 255         State                 42400.0                   72600.0
# 256         State                 41200.0                   72100.0
# 257         State                 38000.0                   70300.0
# 258         State                 37800.0                   66200.0
# 259         State                 39400.0                   63600.0
#
#      Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                              62650.0                           104000.0
# 1                              62650.0                            96000.0
# 2                              59500.0                            81000.0
# 3                                  NaN                            54800.0
# 4                              55000.0                            74700.0
# ..                                 ...                                ...
# 255                            43300.0                            56100.0
# 256                            41700.0                            55600.0
# 257                            35100.0                            51200.0
# 258                            32800.0                            44200.0
# 259                            40400.0                            47900.0
#
#      Mid-Career 75th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                             161000.0                      175571.428571
# 1                             180000.0                      175571.428571
# 2                             149000.0                      201000.000000
# 3                             157000.0                                NaN
# 4                             133000.0                      178000.000000
# ..                                 ...                                ...
# 255                            99600.0                      151000.000000
# 256                            99300.0                      141000.000000
# 257                           100000.0                      179000.000000
# 258                            93300.0                      181000.000000
# 259                            85700.0                      117000.000000
#
# [260 rows x 9 columns]

# %%
#Dodanie kolumny z różnicą zarobków z początku i środka kariery
data["Difference Between Mid-Career and Starting Salary"] = data["Mid-Career Median Salary"] - data["Starting Median Salary"]

# %%
data
# Out:
#                                          School Name        Region  \
# 0           California Institute of Technology (CIT)    California
# 1                                Harvey Mudd College    California
# 2                 University of California, Berkeley    California
# 3                                 Occidental College    California
# 4                           Cal Poly San Luis Obispo    California
# ..                                               ...           ...
# 255                          Fitchburg State College  Northeastern
# 256                              University Of Maine  Northeastern
# 257   State University of New York (SUNY) at Potsdam  Northeastern
# 258  State University of New York (SUNY) at Fredonia  Northeastern
# 259                     University of Southern Maine  Northeastern
#
#       School Type  Starting Median Salary  Mid-Career Median Salary  \
# 0     Engineering                 75500.0                  123000.0
# 1     Engineering                 71800.0                  122000.0
# 2           State                 59900.0                  112000.0
# 3    Liberal Arts                 51900.0                  105000.0
# 4           State                 57200.0                  101000.0
# ..            ...                     ...                       ...
# 255         State                 42400.0                   72600.0
# 256         State                 41200.0                   72100.0
# 257         State                 38000.0                   70300.0
# 258         State                 37800.0                   66200.0
# 259         State                 39400.0                   63600.0
#
#      Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 0                              62650.0                           104000.0
# 1                              62650.0                            96000.0
# 2                              59500.0                            81000.0
# 3                                  NaN                            54800.0
# 4                              55000.0                            74700.0
# ..                                 ...                                ...
# 255                            43300.0                            56100.0
# 256                            41700.0                            55600.0
# 257                            35100.0                            51200.0
# 258                            32800.0                            44200.0
# 259                            40400.0                            47900.0
#
#      Mid-Career 75th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                             161000.0                      175571.428571
# 1                             180000.0                      175571.428571
# 2                             149000.0                      201000.000000
# 3                             157000.0                                NaN
# 4                             133000.0                      178000.000000
# ..                                 ...                                ...
# 255                            99600.0                      151000.000000
# 256                            99300.0                      141000.000000
# 257                           100000.0                      179000.000000
# 258                            93300.0                      181000.000000
# 259                            85700.0                      117000.000000
#
#      Difference Between Mid-Career and Starting Salary
# 0                                              47500.0
# 1                                              50200.0
# 2                                              52100.0
# 3                                              53100.0
# 4                                              43800.0
# ..                                                 ...
# 255                                            30200.0
# 256                                            30900.0
# 257                                            32300.0
# 258                                            28400.0
# 259                                            24200.0
#
# [260 rows x 10 columns]

# %% [markdown]
# # Tabele

# %% [markdown]
# ## Czy początkowe średnie zarobki absolwentów uczelni poszczególnych rodzajów różnią się w zależności od regionu?

# %%
region_start = data.filter(["Region", "School Type", "Starting Median Salary"], axis=1)

# %%
region_start_sort = region_start.groupby(["School Type", "Region"]).median()

# %%
region_start_sort
# Out:
#                            Starting Median Salary
# School Type  Region
# Engineering  California                   73650.0
#              Midwestern                   55900.0
#              Northeastern                 61100.0
#              Southern                     53500.0
#              Western                      54550.0
# Ivy League   California                       NaN
#              Midwestern                       NaN
#              Northeastern                 59850.0
#              Southern                         NaN
#              Western                          NaN
# Liberal Arts California                   48600.0
#              Midwestern                   43400.0
#              Northeastern                 47250.0
#              Southern                     47350.0
#              Western                      40500.0
# Party        California                   50500.0
#              Midwestern                   45500.0
#              Northeastern                 44500.0
#              Southern                     43800.0
#              Western                      47400.0
# State        California                   47600.0
#              Midwestern                   42400.0
#              Northeastern                 44500.0
#              Southern                     43100.0
#              Western                      44900.0

# %% [markdown]
# ## Który region ma najwyższą średnią różnicę między początkowymi a późniejszymi zaróbkami?

# %%
zarobki = data.filter(["Region", "Difference Between Mid-Career and Starting Salary"], axis = 1)

# %%
zarobki_sort = zarobki.groupby(["Region"]).median()

# %%
zarobki_sort
# Out:
#               Difference Between Mid-Career and Starting Salary
# Region
# California                                              41700.0
# Midwestern                                              33700.0
# Northeastern                                            41600.0
# Southern                                                35500.0
# Western                                                 35700.0

# %% [markdown]
# ## Jakie są najwyższe i najniższe mediany zarobków na uczelniach poszczególnych typów?

# %%
imtired = data.groupby("School Type")["Mid-Career Median Salary"].agg(["max", "min"])

# %%
imtired["Difference"] = imtired["max"] - imtired["min"]

# %%
imtired_s = imtired.sort_values(by = "Difference", axis = 0, ascending = True)

# %%
imtired_s
# Out:
#                    max       min  Difference
# School Type
# Party          96100.0   73000.0     23100.0
# Ivy League    134000.0  107000.0     27000.0
# Engineering   126000.0   80000.0     46000.0
# Liberal Arts  110000.0   63900.0     46100.0
# State         112000.0   58200.0     53800.0

# %% [markdown]
# ## Jak duża jest różnica między najwięcej i najmniej zarabiającymi absolwentami szkół z poszczególnych regionów?

# %%
perce = data.groupby("Region")["Mid-Career 10th Percentile Salary", "Mid-Career 90th Percentile Salary"].median()
# Out:
# <ipython-input-17-177f8dfeddc6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   perce = data.groupby("Region")["Mid-Career 10th Percentile Salary", "Mid-Career 90th Percentile Salary"].median()

# %%
perce["Difference"] = perce["Mid-Career 90th Percentile Salary"] - perce["Mid-Career 10th Percentile Salary"]

# %%
perce_s = perce.sort_values(by = "Difference", axis = 0, ascending = True)

# %%
perce_s
# Out:
#               Mid-Career 10th Percentile Salary  \
# Region
# Western                                 41700.0
# Midwestern                              40350.0
# Southern                                42000.0
# California                              47400.0
# Northeastern                            47000.0
#
#               Mid-Career 90th Percentile Salary  Difference
# Region
# Western                                143000.0    101300.0
# Midwestern                             143000.0    102650.0
# Southern                               151000.0    109000.0
# California                             158000.0    110600.0
# Northeastern                           180000.0    133000.0

# %% [markdown]
# ## Jak duża jest różnica między najwięcej i najmniej zarabiającymi absolwentami szkół poszczególnych typów?

# %%
perce2 = data.groupby("School Type")["Mid-Career 10th Percentile Salary", "Mid-Career 90th Percentile Salary"].median()
# Out:
# <ipython-input-21-000c0369fb3d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   perce2 = data.groupby("School Type")["Mid-Career 10th Percentile Salary", "Mid-Career 90th Percentile Salary"].median()

# %%
perce2["Difference"] = perce2["Mid-Career 90th Percentile Salary"] - perce2["Mid-Career 10th Percentile Salary"]

# %%
perce2_s = perce2.sort_values(by = "Difference", axis = 0, ascending = True)

# %%
perce2_s
# Out:
#               Mid-Career 10th Percentile Salary  \
# School Type
# State                                   41900.0
# Engineering                             62650.0
# Party                                   43650.0
# Liberal Arts                            44500.0
# Ivy League                              56350.0
#
#               Mid-Career 90th Percentile Salary     Difference
# School Type
# State                             148000.000000  106100.000000
# Engineering                       175571.428571  112921.428571
# Party                             164500.000000  120850.000000
# Liberal Arts                      189000.000000  144500.000000
# Ivy League                        271500.000000  215150.000000

# %% [markdown]
# # Wizualizacje

# %% [markdown]
# ### 01 Różnice między roczną płacą z początku a z połowy kariery pomiędzy regionami USA

# %%
zarobki_sort = zarobki_sort.sort_values(by = "Difference Between Mid-Career and Starting Salary")

# %%
x = zarobki_sort.index
y = zarobki_sort["Difference Between Mid-Career and Starting Salary"]

fig = plt.figure(figsize=(8,10))

plt.bar(x, y, color=['lightsteelblue', 'lightskyblue', 'skyblue', 'deepskyblue', 'dodgerblue'])

plt.xlabel('Region USA')
plt.ylabel('Różnice między medianą rocznej płacy z początku a z połowy kariery (USD)')
plt.title('Średnie różnice między medianą rocznej płacy z początku \n a z połowy kariery pomiędzy regionami USA')
plt.show()

fig.savefig('wykres_1.png', dpi=500)

# %% [markdown]
# ### 02 Płaca w połowie kariery według uczelni wyższej

# %%
mydata = data.sort_values(by = 'Mid-Career Median Salary', ascending=False)
mydata = mydata.head(50)
mydata = mydata.sort_values(by = 'Mid-Career Median Salary', ascending=True)
mydata
# Out:
#                                            School Name        Region  \
# 66                University of Missouri - Rolla (UMR)    Midwestern
# 218                                      Union College  Northeastern
# 217                              Binghamton University  Northeastern
# 65   University of Illinois at Urbana-Champaign (UIUC)    Midwestern
# 64   University of Illinois at Urbana-Champaign (UIUC)    Midwestern
# 128                               Texas A&M University      Southern
# 216                                      Bates College  Northeastern
# 9               University of California, Irvine (UCI)    California
# 215                  Wentworth Institute of Technology  Northeastern
# 27              University of Colorado - Boulder (UCB)       Western
# 63              Illinois Institute of Technology (IIT)    Midwestern
# 214      Wesleyan University (Middletown, Connecticut)  Northeastern
# 8                      University of California, Davis    California
# 4                             Cal Poly San Luis Obispo    California
# 7                                       Pomona College    California
# 6           University of California, San Diego (UCSD)    California
# 5       University of California at Los Angeles (UCLA)    California
# 213                                   Williams College  Northeastern
# 127                       University of Virginia (UVA)      Southern
# 62                                    Carleton College    Midwestern
# 212                                 Swarthmore College  Northeastern
# 125                      Washington and Lee University      Southern
# 126                                   Davidson College      Southern
# 3                                   Occidental College    California
# 211                    Stevens Institute of Technology  Northeastern
# 124                    Georgia Institute of Technology      Southern
# 26                            Colorado School of Mines       Western
# 210                          College of the Holy Cross  Northeastern
# 209                                    Bowdoin College  Northeastern
# 208                                  Lafayette College  Northeastern
# 207                                    Amherst College  Northeastern
# 206                                Columbia University  Northeastern
# 205                                 Colgate University  Northeastern
# 204                                   Brown University  Northeastern
# 203                                Bucknell University  Northeastern
# 202                                 Cornell University  Northeastern
# 201             Rensselaer Polytechnic Institute (RPI)  Northeastern
# 200                   Carnegie Mellon University (CMU)  Northeastern
# 2                   University of California, Berkeley    California
# 197       Polytechnic University of New York, Brooklyn  Northeastern
# 198                                       Cooper Union  Northeastern
# 199              Worcester Polytechnic Institute (WPI)  Northeastern
# 196                         University of Pennsylvania  Northeastern
# 1                                  Harvey Mudd College    California
# 0             California Institute of Technology (CIT)    California
# 195                                 Harvard University  Northeastern
# 194                                    Yale University  Northeastern
# 193        Massachusetts Institute of Technology (MIT)  Northeastern
# 192                               Princeton University  Northeastern
# 191                                  Dartmouth College  Northeastern
#
#       School Type  Starting Median Salary  Mid-Career Median Salary  \
# 66          State                 57100.0                   95800.0
# 218  Liberal Arts                 47200.0                   95800.0
# 217         State                 53600.0                   95900.0
# 65          State                 52900.0                   96100.0
# 64          Party                 52900.0                   96100.0
# 128         State                 49700.0                   96100.0
# 216  Liberal Arts                 47300.0                   96500.0
# 9           State                 48300.0                   96700.0
# 215   Engineering                 53000.0                   96700.0
# 27          State                 47100.0                   97600.0
# 63    Engineering                 56000.0                   97800.0
# 214  Liberal Arts                 46500.0                   97900.0
# 8           State                 52300.0                   99600.0
# 4           State                 57200.0                  101000.0
# 7    Liberal Arts                 48600.0                  101000.0
# 6           State                 51100.0                  101000.0
# 5           State                 52600.0                  101000.0
# 213  Liberal Arts                 51700.0                  102000.0
# 127         State                 52700.0                  103000.0
# 62   Liberal Arts                 47500.0                  103000.0
# 212  Liberal Arts                 49700.0                  104000.0
# 125  Liberal Arts                 53600.0                  104000.0
# 126  Liberal Arts                 46100.0                  104000.0
# 3    Liberal Arts                 51900.0                  105000.0
# 211   Engineering                 60600.0                  105000.0
# 124   Engineering                 58300.0                  106000.0
# 26    Engineering                 58100.0                  106000.0
# 210  Liberal Arts                 50200.0                  106000.0
# 209  Liberal Arts                 48100.0                  107000.0
# 208  Liberal Arts                 53900.0                  107000.0
# 207  Liberal Arts                 54500.0                  107000.0
# 206    Ivy League                 59400.0                  107000.0
# 205  Liberal Arts                 52800.0                  108000.0
# 204    Ivy League                 56200.0                  109000.0
# 203  Liberal Arts                 54100.0                  110000.0
# 202    Ivy League                 60300.0                  110000.0
# 201   Engineering                 61100.0                  110000.0
# 200   Engineering                 61800.0                  111000.0
# 2           State                 59900.0                  112000.0
# 197   Engineering                 62400.0                  114000.0
# 198   Engineering                 62200.0                  114000.0
# 199   Engineering                 61000.0                  114000.0
# 196    Ivy League                 60900.0                  120000.0
# 1     Engineering                 71800.0                  122000.0
# 0     Engineering                 75500.0                  123000.0
# 195    Ivy League                 63400.0                  124000.0
# 194    Ivy League                 59100.0                  126000.0
# 193   Engineering                 72200.0                  126000.0
# 192    Ivy League                 66500.0                  131000.0
# 191    Ivy League                 58000.0                  134000.0
#
#      Mid-Career 10th Percentile Salary  Mid-Career 25th Percentile Salary  \
# 66                             67600.0                            80400.0
# 218                            48700.0                            75200.0
# 217                            50900.0                            71200.0
# 65                             48200.0                            68900.0
# 64                             48200.0                            68900.0
# 128                            51100.0                            71300.0
# 216                                NaN                            60700.0
# 9                              47800.0                            66000.0
# 215                            55200.0                            74000.0
# 27                             51600.0                            69000.0
# 63                             56100.0                            77400.0
# 214                            42000.0                            62500.0
# 8                              52000.0                            71600.0
# 4                              55000.0                            74700.0
# 7                                  NaN                            63300.0
# 6                              51700.0                            75400.0
# 5                              51300.0                            72500.0
# 213                                NaN                            76400.0
# 127                            52200.0                            71800.0
# 62                                 NaN                            69400.0
# 212                                NaN                            67200.0
# 125                                NaN                            82800.0
# 126                                NaN                            70500.0
# 3                                  NaN                            54800.0
# 211                            68700.0                            81900.0
# 124                            67200.0                            85200.0
# 26                             62200.0                            87900.0
# 210                                NaN                            65600.0
# 209                                NaN                            74600.0
# 208                            70600.0                            79300.0
# 207                                NaN                            84900.0
# 206                            50300.0                            71900.0
# 205                            60000.0                            76700.0
# 204                            55400.0                            74400.0
# 203                            62800.0                            80600.0
# 202                            56800.0                            79800.0
# 201                            71600.0                            85500.0
# 200                            63300.0                            80100.0
# 2                              59500.0                            81000.0
# 197                            66800.0                            94300.0
# 198                            62650.0                            80200.0
# 199                            80000.0                            91200.0
# 196                            55900.0                            79200.0
# 1                              62650.0                            96000.0
# 0                              62650.0                           104000.0
# 195                            54800.0                            86200.0
# 194                            58000.0                            80600.0
# 193                            76800.0                            99200.0
# 192                            68900.0                           100000.0
# 191                            63100.0                            90200.0
#
#      Mid-Career 75th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 66                            122000.0                      166000.000000
# 218                           135000.0                      230000.000000
# 217                           146000.0                      201000.000000
# 65                            132000.0                      177000.000000
# 64                            132000.0                      177000.000000
# 128                           131000.0                      171000.000000
# 216                           162000.0                                NaN
# 9                             123000.0                      172000.000000
# 215                           117000.0                      153000.000000
# 27                            128000.0                      187000.000000
# 63                            121000.0                      165000.000000
# 214                           126000.0                      215000.000000
# 8                             135000.0                      202000.000000
# 4                             133000.0                      178000.000000
# 7                             161000.0                                NaN
# 6                             131000.0                      177000.000000
# 5                             139000.0                      193000.000000
# 213                           143000.0                                NaN
# 127                           146000.0                      215000.000000
# 62                            141000.0                                NaN
# 212                           167000.0                                NaN
# 125                           146000.0                                NaN
# 126                           146000.0                                NaN
# 3                             157000.0                                NaN
# 211                           138000.0                      185000.000000
# 124                           137000.0                      183000.000000
# 26                            142000.0                      201000.000000
# 210                           143000.0                                NaN
# 209                           146000.0                                NaN
# 208                           144000.0                      204000.000000
# 207                           162000.0                                NaN
# 206                           161000.0                      241000.000000
# 205                           167000.0                      265000.000000
# 204                           159000.0                      228000.000000
# 203                           156000.0                      251000.000000
# 202                           160000.0                      210000.000000
# 201                           140000.0                      182000.000000
# 200                           150000.0                      209000.000000
# 2                             149000.0                      201000.000000
# 197                           143000.0                      190000.000000
# 198                           142000.0                      175571.428571
# 199                           137000.0                      180000.000000
# 196                           192000.0                      282000.000000
# 1                             180000.0                      175571.428571
# 0                             161000.0                      175571.428571
# 195                           179000.0                      288000.000000
# 194                           198000.0                      326000.000000
# 193                           168000.0                      220000.000000
# 192                           190000.0                      261000.000000
# 191                           234000.0                      321000.000000
#
#      Difference Between Mid-Career and Starting Salary
# 66                                             38700.0
# 218                                            48600.0
# 217                                            42300.0
# 65                                             43200.0
# 64                                             43200.0
# 128                                            46400.0
# 216                                            49200.0
# 9                                              48400.0
# 215                                            43700.0
# 27                                             50500.0
# 63                                             41800.0
# 214                                            51400.0
# 8                                              47300.0
# 4                                              43800.0
# 7                                              52400.0
# 6                                              49900.0
# 5                                              48400.0
# 213                                            50300.0
# 127                                            50300.0
# 62                                             55500.0
# 212                                            54300.0
# 125                                            50400.0
# 126                                            57900.0
# 3                                              53100.0
# 211                                            44400.0
# 124                                            47700.0
# 26                                             47900.0
# 210                                            55800.0
# 209                                            58900.0
# 208                                            53100.0
# 207                                            52500.0
# 206                                            47600.0
# 205                                            55200.0
# 204                                            52800.0
# 203                                            55900.0
# 202                                            49700.0
# 201                                            48900.0
# 200                                            49200.0
# 2                                              52100.0
# 197                                            51600.0
# 198                                            51800.0
# 199                                            53000.0
# 196                                            59100.0
# 1                                              50200.0
# 0                                              47500.0
# 195                                            60600.0
# 194                                            66900.0
# 193                                            53800.0
# 192                                            64500.0
# 191                                            76000.0

# %%
y = mydata["School Name"]
labels = mydata["School Name"]

fig = plt.figure(figsize=(30,20))

x3 = mydata['Mid-Career 10th Percentile Salary']
plt.scatter(x3, y, color='#bff0f8', label = '10 percentyl zarobków z połowy kariery')
plt.yticks(y, labels)

x4 = mydata['Mid-Career 25th Percentile Salary']
plt.scatter(x4, y, color='#6cb2ef', label = '25 percentyl (Q1) zarobków z połowy kariery')

x1 = mydata["Mid-Career Median Salary"]
plt.scatter(x1, y, color='#1986e6', label='Mediana zarobków z połowy kariery')

x5 = mydata['Mid-Career 75th Percentile Salary']
plt.scatter(x5, y, color='#8d6cef', label = '75 percentyl (Q2) zarobków z połowy kariery')

x6 = mydata['Mid-Career 90th Percentile Salary']
plt.scatter(x6, y, color='#cdbff8', label = '90 percentyl zarobków z połowy kariery')

#x2 = mydata['Starting Median Salary']
#plt.scatter(x2, y, color='#ef6c6c', marker="*", label='Mediana zarobków z początku kariery')

plt.xlabel('Roczne zarobki abolwentów [USD]')
plt.title('Roczne zarobki absolwentów 50 uczelni \n z najwyższą medianą zarobków z połowy kariery')
plt.legend(loc='lower right')
plt.show()

fig.savefig('wykres_2.png', dpi=300)
